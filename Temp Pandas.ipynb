# %%
import pandas as pd
import numpy as np

# %%
# DataFrame
df = pd.read_csv("./ctemp.csv")
# Out:
# C:\Users\Bhargav\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (2906327, 8)

# %%
df.head()
# Out:
#    Region  Country State     City  Month  Day  Year  AvgTemperature
# 0  Africa  Algeria   NaN  Algiers      1    1  1995            64.2
# 1  Africa  Algeria   NaN  Algiers      1    2  1995            49.4
# 2  Africa  Algeria   NaN  Algiers      1    3  1995            48.8
# 3  Africa  Algeria   NaN  Algiers      1    4  1995            46.4
# 4  Africa  Algeria   NaN  Algiers      1    5  1995            47.9

# %%
df.tail(3)
# Out:
#                 Region Country                   State                  City  \
# 2906324  North America      US  Additional Territories  San Juan Puerto Rico
# 2906325  North America      US  Additional Territories  San Juan Puerto Rico
# 2906326  North America      US  Additional Territories  San Juan Puerto Rico
#
#          Month  Day  Year  AvgTemperature
# 2906324      7   29  2013            84.2
# 2906325      7   30  2013            83.8
# 2906326      7   31  2013            83.6

# %%
df
# Out:
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# convert DF -> numpy
tmpr = pd.read_csv("ctemp.csv").values

# %%
tmpr[:, :-1]
# Out:
# array([['Africa', 'Algeria', nan, ..., 1, 1, 1995],
#        ['Africa', 'Algeria', nan, ..., 1, 2, 1995],
#        ['Africa', 'Algeria', nan, ..., 1, 3, 1995],
#        ...,
#        ['North America', 'US', 'Additional Territories', ..., 7, 29,
#         2013],
#        ['North America', 'US', 'Additional Territories', ..., 7, 30,
#         2013],
#        ['North America', 'US', 'Additional Territories', ..., 7, 31,
#         2013]], dtype=object)

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'State', 'City', 'Month', 'Day', 'Year',
#        'AvgTemperature'],
#       dtype='object')

# %%
df['Country']
# Out:
# 0          Algeria
# 1          Algeria
# 2          Algeria
# 3          Algeria
# 4          Algeria
#             ...
# 2906322         US
# 2906323         US
# 2906324         US
# 2906325         US
# 2906326         US
# Name: Country, Length: 2906327, dtype: object

# %%
type(df['Country'])
# Out:
# pandas.core.series.Series

# %%
df[['State','City']]
# Out:
#                           State                  City
# 0                           NaN               Algiers
# 1                           NaN               Algiers
# 2                           NaN               Algiers
# 3                           NaN               Algiers
# 4                           NaN               Algiers
# ...                         ...                   ...
# 2906322  Additional Territories  San Juan Puerto Rico
# 2906323  Additional Territories  San Juan Puerto Rico
# 2906324  Additional Territories  San Juan Puerto Rico
# 2906325  Additional Territories  San Juan Puerto Rico
# 2906326  Additional Territories  San Juan Puerto Rico
#
# [2906327 rows x 2 columns]

# %%
pd.Series([1,10,20,30], index="x y z w".split())
# Out:
# x     1
# y    10
# z    20
# w    30
# dtype: int64

# %%
arr = np.random.randint(1, 100, size=(175,3))

# %%
pd.DataFrame(arr[:, :-1], columns=['f1', 'f2'])
# Out:
#      f1  f2
# 0    75  23
# 1    69  79
# 2    64  16
# 3    16  95
# 4    26  40
# ..   ..  ..
# 170  19  55
# 171  80  10
# 172   5  32
# 173   1  95
# 174  54  62
#
# [175 rows x 2 columns]

# %%
df.iloc[1]
# Out:
# Region             Africa
# Country           Algeria
# State                 NaN
# City              Algiers
# Month                   1
# Day                     2
# Year                 1995
# AvgTemperature       49.4
# Name: 1, dtype: object

# %%
df.iloc[:3]
# Out:
#    Region  Country State     City  Month  Day  Year  AvgTemperature
# 0  Africa  Algeria   NaN  Algiers      1    1  1995            64.2
# 1  Africa  Algeria   NaN  Algiers      1    2  1995            49.4
# 2  Africa  Algeria   NaN  Algiers      1    3  1995            48.8

# %%
df.describe()
# Out:
#               Month           Day          Year  AvgTemperature
# count  2.906327e+06  2.906327e+06  2.906327e+06    2.906327e+06
# mean   6.469163e+00  1.571682e+01  2.006624e+03    5.600492e+01
# std    3.456489e+00  8.800534e+00  2.338226e+01    3.212359e+01
# min    1.000000e+00  0.000000e+00  2.000000e+02   -9.900000e+01
# 25%    3.000000e+00  8.000000e+00  2.001000e+03    4.580000e+01
# 50%    6.000000e+00  1.600000e+01  2.007000e+03    6.250000e+01
# 75%    9.000000e+00  2.300000e+01  2.013000e+03    7.550000e+01
# max    1.200000e+01  3.100000e+01  2.020000e+03    1.100000e+02

# %%
df
# Out:
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %%
df['Region']  = df['Country'] + df['State'] + df['City'] + df['City'] # We have change the region to NaN * NaN = Not a Number

# %%
df['total']  = df['Country'] + df['State'] + df['City'] + df['City']

# %%
df
# Out:
#                                                     Region  Country  \
# 0                                                      NaN  Algeria
# 1                                                      NaN  Algeria
# 2                                                      NaN  Algeria
# 3                                                      NaN  Algeria
# 4                                                      NaN  Algeria
# ...                                                    ...      ...
# 2906322  USAdditional TerritoriesSan Juan Puerto RicoSa...       US
# 2906323  USAdditional TerritoriesSan Juan Puerto RicoSa...       US
# 2906324  USAdditional TerritoriesSan Juan Puerto RicoSa...       US
# 2906325  USAdditional TerritoriesSan Juan Puerto RicoSa...       US
# 2906326  USAdditional TerritoriesSan Juan Puerto RicoSa...       US
#
#                           State                  City  Month  Day  Year  \
# 0                           NaN               Algiers      1    1  1995
# ...

# %%
df.drop(columns=['total'], inplace= True)

# %%
df.head()
# Out:
#   Region  Country State     City  Month  Day  Year  AvgTemperature
# 0    NaN  Algeria   NaN  Algiers      1    1  1995            64.2
# 1    NaN  Algeria   NaN  Algiers      1    2  1995            49.4
# 2    NaN  Algeria   NaN  Algiers      1    3  1995            48.8
# 3    NaN  Algeria   NaN  Algiers      1    4  1995            46.4
# 4    NaN  Algeria   NaN  Algiers      1    5  1995            47.9

# %%
df.isna().sum()
# Out:
# Region            1450990
# Country                 0
# State             1450990
# City                    0
# Month                   0
# Day                     0
# Year                    0
# AvgTemperature          0
# dtype: int64

# %%
df['Year'].nunique()
# Out:
# 28

# %%
df['Year'].unique()
# Out:
# array([1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018, 2019, 2020,  201,  200], dtype=int64)

# %%
df['Year'].value_counts()
# Out:
# 2000    119682
# 1999    119355
# 2001    119355
# 2002    119355
# 2003    119140
# 1998    119082
# 1996    118951
# 1997    118656
# 2004    118645
# 1995    118616
# 2005    117895
# 2006    117647
# 2010    115627
# 2007    115428
# 2008    114908
# 2009    114247
# 2011    113740
# 2012    111993
# 2013    111021
# 2014    109018
# 2015    107498
# 2016    107237
# 2017    106946
# 2018    106698
# 2019    106337
# 2020     38810
# 201        351
# 200         89
# Name: Year, dtype: int64

# %%
# extract all rows where you have Year = 1995

# %%
df[ df['Year'] == 1995 ]
# Out:
#                                                     Region  Country  \
# 0                                                      NaN  Algeria
# 1                                                      NaN  Algeria
# 2                                                      NaN  Algeria
# 3                                                      NaN  Algeria
# 4                                                      NaN  Algeria
# ...                                                    ...      ...
# 2899900  USAdditional TerritoriesSan Juan Puerto RicoSa...       US
# 2899901  USAdditional TerritoriesSan Juan Puerto RicoSa...       US
# 2899902  USAdditional TerritoriesSan Juan Puerto RicoSa...       US
# 2899903  USAdditional TerritoriesSan Juan Puerto RicoSa...       US
# 2899904  USAdditional TerritoriesSan Juan Puerto RicoSa...       US
#
#                           State                  City  Month  Day  Year  \
# 0                           NaN               Algiers      1    1  1995
# ...

# %%
df.iloc[[2,7,3,8,1,9,80]]
# Out:
#    Region  Country State     City  Month  Day  Year  AvgTemperature
# 2     NaN  Algeria   NaN  Algiers      1    3  1995            48.8
# 7     NaN  Algeria   NaN  Algiers      1    8  1995            49.1
# 3     NaN  Algeria   NaN  Algiers      1    4  1995            46.4
# 8     NaN  Algeria   NaN  Algiers      1    9  1995            49.0
# 1     NaN  Algeria   NaN  Algiers      1    2  1995            49.4
# 9     NaN  Algeria   NaN  Algiers      1   10  1995            51.9
# 80    NaN  Algeria   NaN  Algiers      3   22  1995            51.4
